# %% [markdown]
# <a href="https://colab.research.google.com/github/unlimitedaki/pretrained-MLM-for-paragraph-generation/blob/master/rerank_csqa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
from google.colab import drive
drive.mount("/content/drive")
# %cd /content/drive/Shared drives/CS lab/rerank_CSQA
# Out:
# Wed Aug 19 07:53:20 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# Out:
# apex		       etc.py		   model.py	rerank_csqa
# attRankerProcessor.py  external_libraries  OMCS		src_apex
# dataset		       model		   __pycache__	train_att_ranker.py

# %%
# %cd /content/drive/Shared drives/CS lab/rerank_CSQA
# !pip install transformers==2.11.0 -t external_libraries/
# !mkdir src_apex
# %cd src_apex
# !git clone https://github.com/NVIDIA/apex
# %cd apex
# !pip install -v --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./ -t ../../external_libraries
# Out:
# /content/drive/Shared drives/CS lab/rerank_CSQA
# /content/drive/Shared drives/CS lab/rerank_CSQA/src_apex
# /content/drive/Shared drives/CS lab/rerank_CSQA/src_apex/apex
# /usr/local/lib/python3.6/dist-packages/pip/_internal/commands/install.py:283: UserWarning: Disabling all use of wheels due to the use of --build-options / --global-options / --install-options.
#   cmdoptions.check_install_build_global(options)
# Created temporary directory: /tmp/pip-target-lvmqao1j
# Created temporary directory: /tmp/pip-ephem-wheel-cache-2pl20cuz
# Created temporary directory: /tmp/pip-req-tracker-5y9gapyt
# Created requirements tracker '/tmp/pip-req-tracker-5y9gapyt'
# Created temporary directory: /tmp/pip-install-1u28x0s2
# Processing /content/drive/Shared drives/CS lab/rerank_CSQA/src_apex/apex
#   Created temporary directory: /tmp/pip-req-build-_2s1ywno
#   Added file:///content/drive/Shared%20drives/CS%20lab/rerank_CSQA/src_apex/apex to build tracker '/tmp/pip-req-tracker-5y9gapyt'
# ...

# %%
import os, sys
if os.path.exists("external_libraries"):
    sys.path.append('external_libraries')

import transformers

# %%
# %cd /content/drive/Shared drives/CS lab/rerank_CSQA
# !python train_att_ranker.py \
    --save_model_name "att_ranker_2e-5_QAconcept_cslen5_concat_linear" \
    --cs_len 5 \
    --learning_rate 2e-5 \
    --cs_mode "QAconcept-Match" \
    --num_train_epochs 5 \
    --train_batch_size 5 \
    --eval_batch_size 5 \
    --fp16 False \
    --cs_dir "" \
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Iteration:  83% 1626/1949 [13:49<02:43,  1.97it/s]
# Iteration:  83% 1627/1949 [13:50<02:43,  1.96it/s]
# Iteration:  84% 1628/1949 [13:50<02:43,  1.96it/s]
# Iteration:  84% 1629/1949 [13:51<02:43,  1.96it/s]
# Iteration:  84% 1630/1949 [13:51<02:42,  1.97it/s]
# Iteration:  84% 1631/1949 [13:52<02:41,  1.97it/s]
# Iteration:  84% 1632/1949 [13:52<02:41,  1.96it/s]
# Iteration:  84% 1633/1949 [13:53<02:40,  1.97it/s]
# Iteration:  84% 1634/1949 [13:53<02:40,  1.97it/s]
# Iteration:  84% 1635/1949 [13:54<02:38,  1.98it/s]
# Iteration:  84% 1636/1949 [13:54<02:39,  1.96it/s]
# Iteration:  84% 1637/1949 [13:55<02:38,  1.97it/s]
# Iteration:  84% 1638/1949 [13:55<02:38,  1.96it/s]
# Iteration:  84% 1639/1949 [13:56<02:38,  1.96it/s]
# Iteration:  84% 1640/1949 [13:56<02:37,  1.97it/s]
# Iteration:  84% 1641/1949 [13:57<02:36,  1.97it/s]
# Iteration:  84% 1642/1949 [13:57<02:36,  1.97it/s]
# Iteration:  84% 1643/1949 [13:58<02:34,  1.98it/s]
# ...

# %%
# !ls
# Out:
# drive  sample_data

# %%
p cs_result_file
p args.cs_mode
# Out:
#   File "<ipython-input-5-dc2dfdec38d0>", line 1
#     p cs_result_file
#                    ^
# SyntaxError: invalid syntax

# %%
p example.context
p len(choices_features)
p input_ids.shape
p input_ids.shape[0:2]
p mean_pooled_output.shape
p reshaped_output.shape
meeeen = atten_output.mean(dim=1)
p meeeen.shape
